# %% [markdown]
# <a href="https://colab.research.google.com/github/UktamSam/AI_Foundation/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford", "Ferrari", "RR", "KIA", "Genesis"],
  'counts': [3, 7, 2, 2, 1, 4, 9]
}
print('mydataset:',mydataset)

df = pd.DataFrame(mydataset)
print('df:', df)
# Out:
# mydataset: {'cars': ['BMW', 'Volvo', 'Ford', 'Ferrari', 'RR', 'KIA', 'Genesis'], 'counts': [3, 7, 2, 2, 1, 4, 9]}
# df:       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3  Ferrari       2
# 4       RR       1
# 5      KIA       4
# 6  Genesis       9

# %%
df.head() # default 5 rows
# Out:
#       cars  counts
# 0      BMW       3
# 1    Volvo       7
# 2     Ford       2
# 3  Ferrari       2
# 4       RR       1

# %%
df.tail() # oxiridan 5 rows default
# Out:
#       cars  counts
# 2     Ford       2
# 3  Ferrari       2
# 4       RR       1
# 5      KIA       4
# 6  Genesis       9

# %%
df.shape # 7-row, 2-columns
# Out:
# (7, 2)

# %%
df.columns
# Out:
# Index(['cars', 'counts'], dtype='object')

# %%
df.dtypes
# Out:
# cars      object
# counts     int64
# dtype: object

# %%
df.describe() # numerical columns only; std - raqamlar qanchalik uzoq bir birovidan
# Out:
#         counts
# count  7.00000
# mean   4.00000
# std    2.94392
# min    1.00000
# 25%    2.00000
# 50%    3.00000
# 75%    5.50000
# max    9.00000

# %%
df.iloc[0:3] # index orqali malumotni chiqarib beradi.
# Out:
#     cars  counts
# 0    BMW       3
# 1  Volvo       7
# 2   Ford       2

# %%
df.loc[:, 'cars']
# Out:
# 0        BMW
# 1      Volvo
# 2       Ford
# 3    Ferrari
# 4         RR
# 5        KIA
# 6    Genesis
# Name: cars, dtype: object

# %%
df['counts']>5
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# Name: counts, dtype: bool

# %%
df[df['counts']>4]
# Out:
#       cars  counts
# 1    Volvo       7
# 6  Genesis       9

# %%
df.mean(numeric_only=True)
# Out:
# counts    4.0
# dtype: float64

# %%
df.sum() #max, min, count, median, std
# Out:
# cars      BMWVolvoFordFerrariRRKIAGenesis
# counts                                 28
# dtype: object

# %%
data_with_missing = {
    "cars": ["BMW", "VOLVO", None, "Tesla", "Ferrari", None, "Ford"],
    "counts": [3, 8, None, 8, 1, 9, None]
}
df_missing = pd.DataFrame(data_with_missing)

print(df_missing)
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    VOLVO     8.0
# 2     None     NaN
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5     None     9.0
# 6     Ford     NaN

# %%
df_missing.isnull().sum()
# Out:
# cars      2
# counts    2
# dtype: int64

# %%
df_missing.dropna() # how='all'; axis; subset=['counts']
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    VOLVO     8.0
# 3    Tesla     8.0
# 4  Ferrari     1.0

# %%
df_missing.fillna({"cars": "unknown", "counts": 0})
# Out:
#       cars  counts
# 0      BMW     3.0
# 1    VOLVO     8.0
# 2  unknown     0.0
# 3    Tesla     8.0
# 4  Ferrari     1.0
# 5  unknown     9.0
# 6     Ford     0.0

# %%
df = pd.read_csv("Titanic-Dataset.csv")
df.head(10)

# df = pd.read_excel("etwery.xlsx")
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.to_excel("output.xlsx")

# %%
#Series => 1D
cars = pd.Series(["BMW", "Tesla", "Ford"])
print('cars:', cars)
# Out:
# cars: 0      BMW
# 1    Tesla
# 2     Ford
# dtype: object
